# %%
import numpy as np
import folium
data = (
    np.random.normal(size=(100, 3)) *
    np.array([[0.1, 0.1, 0]]) +
    np.array([[40, 116.5, 1]])
).tolist()
print(data)
# HeatMap
from folium.plugins import HeatMap
m = folium.Map([39.93, 116.38], tiles='stamentoner', zoom_start=6)
HeatMap(data).add_to(m)
# Out:
# [[40.13948762763824, 116.3997679410242, 1.0], [39.944812664325376, 116.68051888958716, 1.0], [39.9937975541785, 116.43637677382347, 1.0], [39.98214939748987, 116.50120703518755, 1.0], [39.98026662926429, 116.71803640826154, 1.0], [40.120386516628315, 116.57912840495302, 1.0], [39.892075847520395, 116.3915238297304, 1.0], [40.01454328537045, 116.3479592951284, 1.0], [39.97354445950155, 116.461766606751, 1.0], [40.11731568496953, 116.5398320149873, 1.0], [39.947534056642766, 116.41616597581913, 1.0], [39.89083519455025, 116.49533686934622, 1.0], [40.04612008615469, 116.61855461846928, 1.0], [40.17503020189833, 116.57502753146214, 1.0], [39.91032323238757, 116.51583443904074, 1.0], [39.88159309917578, 116.53643963746624, 1.0], [39.89105516254239, 116.3977019877357, 1.0], [40.23538196275866, 116.45556539894129, 1.0], [40.10861920306412, 116.45996199841746, 1.0], [40.05978170922742, 116.57098103613772, 1.0], [39.9470230583748, 116.43705791370564, 1.0], [39.93540897961988, 116.771799338239
# ...

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
a = '123'
a = a.split('2')
a = [a[0],a[1],1]
a
# Out:
# ['1', '3', 1]

# %%
import pandas as pd   
import requests
import re
def get_location(data):
    if (type(data)==list):
        df = pd.DataFrame(data)
    else:
        df = data 
        df.columns = [0]
    NS = []
    EW = []
    API_KEY = 'AIzaSyAs6-J9FUtWIIXYmyltuJ-DqSNigyIG2gc'

    for i in range(len(df)):
        a = len(NS)
        try:
            address = df[0][i]
            address = re.sub(r'公[里尺][處]*', '', address)
            address = re.sub(r'[巷街]口', '', address)
            address = re.sub(r'臺南市南區健康路２段502號前','臺南市南區健康路２段504號前',address)
            #print(address)
            params = {
                'key' : API_KEY,
                'address' : address
            }

            base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
            response = requests.get(base_url, params=params).json()
            response.keys()
        except:
            print(address)
            print('========================')


        if response['status'] == 'OK':
            geometry = response['results'][0]['geometry']
            lng = geometry['location']['lng']
            lat = geometry['location']['lat']
            EW.append(lng)
            NS.append(lat)
            #print('選擇:',i)
            #print(lng,lat)
            #print('==============================')
        else:
            EW.append('22.996783')
            NS.append('120.219639')
            #print('========================')
        b = len(NS) -a
        if(b != 1):
            print(address)
            print('數量',b)
            print(lng,'   ',lat)
            print('==============================')


    output_df = pd.DataFrame({'緯度':NS,'經度':EW})
    return output_df



datas = pd.read_csv('https://data.tainan.gov.tw/dataset/e37984b0-6f37-472b-98e3-adf57f87b416/resource/e13df319-cbb8-496f-adc4-6b87144f5af9/download/10901-12.csv')
datas = datas.append(pd.read_csv('https://data.tainan.gov.tw/dataset/e37984b0-6f37-472b-98e3-adf57f87b416/resource/0e2ab9fc-1eee-4a0d-b0a4-baf6840f5ee2/download/10801-12.csv'))
datas = datas.append(pd.read_csv('https://data.tainan.gov.tw/dataset/e37984b0-6f37-472b-98e3-adf57f87b416/resource/8b7d7619-d2a1-433d-b713-2e9d1beaad20/download/107.csv'))
datas = datas.append(pd.read_csv('https://data.tainan.gov.tw/dataset/e37984b0-6f37-472b-98e3-adf57f87b416/resource/179d94b7-f521-4a30-a0f8-77fd128f8130/download/106.csv'))
data0 = datas['小型汽車']
data1 = datas['大型汽車']
data2 = datas['大型重型機車']
ans = pd.DataFrame({'小型汽車':data0,'大型汽車':data1,'大型重型機車':data2})
#data = datas['重型機車']+datas['輕型機車']
#data1 = '臺南市'+datas['區域']+datas['路段']
#data = pd.DataFrame({'機車拖吊':data,'位置':data1})
#data1 = pd.DataFrame({'位置':data1})
#data1.index = range(len(data1))
#data2 = get_location(data1)
#print(data2)

# %%
#output_data = pd.concat([data,data2],axis = 1)
ans.to_csv('botang1.csv',encoding = 'utf-8-sig',index = False)

# %%
from math import radians, cos, sin, asin, sqrt
 
def haversine(lon1, lat1, lon2, lat2): 
  
    # 将十进制度数转化为弧度
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
 
    # haversine公式
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # 地球平均半径，单位为公里
    return c * r
